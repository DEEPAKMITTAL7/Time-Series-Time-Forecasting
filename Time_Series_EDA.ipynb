# %%
# Importing libraries for data manipulation
import pandas as pd
import pandas_datareader as pdr
import numpy as np

# Importing libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Importing libraries for datetime
from datetime import datetime

# Impoerting library for data
import yfinance as yf

# %%
df_tesla = yf.download('TSLA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_tesla.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
df_tesla['Close'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Close'].plot(xlim=['2020-01-01','2025-04-02'], figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2025-03-20', '2025-03-21', '2025-03-24', '2025-03-25',
#                '2025-03-26', '2025-03-27', '2025-03-28', '2025-03-31',
#                '2025-04-01', '2025-04-02'],
#               dtype='datetime64[ns]', name='Date', length=3714, freq=None)

# %%
df_tesla.index[:4]
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df_tesla.loc['2010-06-29':'2010-07-02']['Close']
# Out:
# Ticker          TSLA
# Date
# 2010-06-29  1.592667
# 2010-06-30  1.588667
# 2010-07-01  1.464000
# 2010-07-02  1.280000

# %%
figure, axis = plt.subplots(figsize=(12,4))
axis.plot(df_tesla.index, df_tesla['Close'])

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3714 entries, 2010-06-29 to 2025-04-02
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   3714 non-null   float64
#  1   (High, TSLA)    3714 non-null   float64
#  2   (Low, TSLA)     3714 non-null   float64
#  3   (Open, TSLA)    3714 non-null   float64
#  4   (Volume, TSLA)  3714 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 303.1 KB

# %%
df_tesla
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2010-06-29    1.592667    1.666667    1.169333    1.266667  281494500
# 2010-06-30    1.588667    2.028000    1.553333    1.719333  257806500
# 2010-07-01    1.464000    1.728000    1.351333    1.666667  123282000
# 2010-07-02    1.280000    1.540000    1.247333    1.533333   77097000
# 2010-07-06    1.074000    1.333333    1.055333    1.333333  103003500
# ...                ...         ...         ...         ...        ...
# 2025-03-27  273.130005  291.850006  271.820007  272.480011  162572100
# 2025-03-28  263.549988  276.100006  260.570007  275.579987  123809400
# 2025-03-31  259.160004  260.559998  243.360001  249.309998  134008900
# 2025-04-01  268.459991  277.450012  259.250000  263.799988  145924600
# 2025-04-02  281.880005  284.389893  251.270004  254.600006  144461393
#
# [3714 rows x 5 columns]

# %%
df_tesla.Close
# Out:
# Ticker            TSLA
# Date
# 2010-06-29    1.592667
# 2010-06-30    1.588667
# 2010-07-01    1.464000
# 2010-07-02    1.280000
# 2010-07-06    1.074000
# ...                ...
# 2025-03-27  273.130005
# 2025-03-28  263.549988
# 2025-03-31  259.160004
# 2025-04-01  268.459991
# 2025-04-02  281.880005
#
# [3714 rows x 1 columns]

# %%
df_tesla.High.values
# Out:
# array([[  1.66666698],
#        [  2.02800012],
#        [  1.72800004],
#        ...,
#        [260.55999756],
#        [277.45001221],
#        [284.38989258]])

# %%
max(df_tesla.High.values)
# Out:
# array([488.54000854])

# %%
min(df_tesla.Low.values)
# Out:
# array([0.998667])

# %%
df_tesla.loc[df_tesla.High.idxmax()]
# Out:
# Price            Close        High        Low   Open     Volume
# Ticker            TSLA        TSLA       TSLA   TSLA       TSLA
# Date
# 2024-12-18  440.130005  488.540009  427.01001  466.5  149340800

# %%
df_tesla.loc[df_tesla.Low.idxmin()].index
# Out:
# DatetimeIndex(['2010-07-07'], dtype='datetime64[ns]', name='Date', freq=None)
